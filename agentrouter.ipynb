# %%
from openai import OpenAI

# Initialize the client pointing to AgentRouter's OpenAI-compatible endpoint
client = OpenAI(
    base_url="https://agentrouter.org/v1",
    api_key="sk-GYg7gkGbc3MWrdAgCr86oXAdYIjLsRQyILQK7C5Tw3qe3xdW"
)

try:
    response = client.chat.completions.create(
        model="claude-sonnet-4-5-20250929",
        messages=[
            {"role": "user", "content": "Hello! Confirming the API connection works."}
        ]
    )
    print(response.choices[0].message.content)
except Exception as e:
    print(f"API Error: {e}")
# Out:
# API Error: Error code: 401 - {'error': {'message': 'unauthorized client detected, contact support for assistance at https://discord.gg/aYq5B4RW3'}, 'message': 'UNAUTHENTICATED', 'success': False, 'type': 'unauthorized_client_error'}
