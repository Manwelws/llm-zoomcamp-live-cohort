# %%
import numpy 
import tqdm

# %%
from embedder import Embedder

model = Embedder()
# Out:
# 2026-06-25 09:18:16.554024382 [W:onnxruntime:Default, device_discovery.cc:133 GetPciBusId] Skipping pci_bus_id for PCI path at "/sys/devices/LNXSYSTM:00/LNXSYBUS:00/PNP0A03:00/device:07/VMBUS:01/5620e0c7-8062-4dce-aeb7-520c7ef76171" because filename "5620e0c7-8062-4dce-aeb7-520c7ef76171" did not match expected pattern of [0-9a-f]+:[0-9a-f]+:[0-9a-f]+[.][0-9a-f]+

# %%
v = model.encode(text="How does approximate nearest neighbor search work?")
v[0]
# Out:
# np.float64(-0.02058203437252893)

# %%
from gitsource import GithubRepositoryDataReader

reader = GithubRepositoryDataReader(
    repo_owner="DataTalksClub",
    repo_name="llm-zoomcamp",
    commit_id="8c1834d",
    allowed_extensions={"md"},
    filename_filter=lambda path: "/lessons/" in path,
)

documents = [file.parse() for file in reader.read()]

# %%
target_filename = "02-vector-search/lessons/07-sqlitesearch-vector.md"

# Finds the first match, or returns None if it doesn't exist
target_document = next((doc for doc in documents if doc['filename'] == target_filename), None)

content = target_document['content']

# %%
dv = model.encode(content)
dv.dot(v)
# Out:
# np.float64(0.36107026789538205)

# %%
from gitsource import chunk_documents
chunks = chunk_documents(documents, size=2000, step=1000)

# %%
batch_size = 50
vectors = []

for i in tqdm(range(0,len(texts),batch_size)):
    batch = texts[i:i + batch_size]
    batch_vectors = model.encode(batch)
    vectors.extend(batch_vectors)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 4
#       1 batch_size = 50
#       2 vectors = []
#       3
# ----> 4 for i in tqdm(range(0,len(texts),batch_size)):
#       5     batch = texts[i:i + batch_size]
#       6     batch_vectors = model.encode(batch)
#       7     vectors.extend(batch_vectors)
#
# NameError: name 'tqdm' is not defined

# %%
scores = dv.dot(v)
Highest = np.argmax(scores)
